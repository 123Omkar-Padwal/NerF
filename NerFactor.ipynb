# %%
# !git clone --recursive https://github.com/google/nerfactor.git
# Out:
# Cloning into 'nerfactor'...
# remote: Enumerating objects: 1113, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 1113 (delta 8), reused 14 (delta 6), pack-reused 1093
# Receiving objects: 100% (1113/1113), 40.51 MiB | 21.11 MiB/s, done.
# Resolving deltas: 100% (665/665), done.

# %%
cd nerfactor
# Out:
# /content/nerfactor

# %%
################################################################################
# INSTALL CONDA ON GOOGLE COLAB
################################################################################
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2022-07-21 15:25:26--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’
#
# Miniconda3-py37_4.8 100%[===================>]  81.12M   195MB/s    in 0.4s
#
# 2022-07-21 15:25:26 (195 MB/s) - ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
# ...

# %%
# !conda info
# Out:
#      active environment : None
#        user config file : /root/.condarc
#  populated config files :
#           conda version : 4.8.2
#     conda-build version : not installed
#          python version : 3.7.6.final.0
#        virtual packages : __glibc=2.27
#        base environment : /usr/local  (writable)
#            channel URLs : https://repo.anaconda.com/pkgs/main/linux-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/linux-64
#                           https://repo.anaconda.com/pkgs/r/noarch
#           package cache : /usr/local/pkgs
#                           /root/.conda/pkgs
#        envs directories : /usr/local/envs
#                           /root/.conda/envs
#                platform : linux-64
#              user-agent : conda/4.8.2 requests/2.22.0 CPython/3.7.6 Linux/5.4.188+ ubuntu/18.04.5 glibc/2.27
#                 UID:GID : 0:0
#              netrc file : None
# ...

# %%
# !conda install pip
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - pip
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2022.4.26  |       h06a4308_0         124 KB
#     certifi-2022.6.15          |   py37h06a4308_0         153 KB
#     conda-4.13.0               |   py37h06a4308_0         890 KB
#     pip-22.1.2                 |   py37h06a4308_0         2.4 MB
#     ------------------------------------------------------------
#                                            Total:         3.6 MB
#
# The following packages will be UPDATED:
#
#   openssl               anaconda::openssl-1.1.1o-h7f8727e_0 --> pkgs/main::openssl-1.1.1q-h7f8727e_0
#   pip                                         20.0.2-py37_1 --> 22.1.2-py37h06a4308_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
# ...

# %%
# !conda install -c anaconda scipy
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.13.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - scipy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |              mkl           6 KB  anaconda
#     ca-certificates-2022.4.26  |       h06a4308_0         132 KB  anaconda
#     certifi-2022.6.15          |   py37h06a4308_0         156 KB  anaconda
#     conda-4.13.0               |   py37h06a4308_0         990 KB  anaconda
#     intel-openmp-2021.4.0      |    h06a4308_3561         8.8 MB  anaconda
#     libgfortran-ng-7.5.0       |      ha8ba4b0_17          22 KB  anaconda
# ...

# %%
# !conda install -c anaconda ipython
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - ipython
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     backcall-0.2.0             |     pyhd3eb1b0_0          13 KB  anaconda
#     decorator-5.1.1            |     pyhd3eb1b0_0          12 KB  anaconda
#     ipython-7.31.1             |   py37h06a4308_0         1.1 MB  anaconda
#     jedi-0.18.1                |   py37h06a4308_1        1001 KB  anaconda
#     matplotlib-inline-0.1.2    |     pyhd3eb1b0_2          12 KB  anaconda
#     parso-0.8.3                |     pyhd3eb1b0_0          69 KB  anaconda
#     pexpect-4.8.0              |     pyhd3eb1b0_3          51 KB  anaconda
#     pickleshare-0.7.5          |  pyhd3eb1b0_1003          13 KB  anaconda
#     prompt-toolkit-3.0.20      |     pyhd3eb1b0_0         254 KB  anaconda
# ...

# %%
# !conda install -c conda-forge tqdm
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - tqdm
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2022.6.15  |       ha878542_0         149 KB  conda-forge
#     certifi-2022.6.15          |   py37h89c1867_0         155 KB  conda-forge
#     colorama-0.4.5             |     pyhd8ed1ab_0          18 KB  conda-forge
#     conda-4.13.0               |   py37h89c1867_1         989 KB  conda-forge
#     openssl-1.1.1q             |       h7f8727e_0         2.5 MB
#     python_abi-3.7             |          2_cp37m           4 KB  conda-forge
#     tqdm-4.64.0                |     pyhd8ed1ab_0          81 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.9 MB
#
# ...

# %%
# !conda install -c anaconda pillow
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - pillow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     freetype-2.11.0            |       h70c0345_0         943 KB  anaconda
#     giflib-5.2.1               |       h7b6447c_0          82 KB  anaconda
#     jpeg-9e                    |       h7f8727e_0         273 KB  anaconda
#     lcms2-2.12                 |       h3be6417_0         396 KB  anaconda
#     libpng-1.6.37              |       hbc83047_0         364 KB  anaconda
#     libtiff-4.2.0              |       h85742a9_0         640 KB  anaconda
#     libwebp-1.2.2              |       h55f646e_0          88 KB  anaconda
#     libwebp-base-1.2.2         |       h7f8727e_0         869 KB  anaconda
#     lz4-c-1.9.3                |       h295c915_1         216 KB  anaconda
# ...

# %%
# !conda install -c conda-forge opencv
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - opencv
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |            2_gnu          23 KB  conda-forge
#     alsa-lib-1.2.6.1           |       h7f98852_0         578 KB  conda-forge
#     aom-3.4.0                  |       h27087fc_1         2.7 MB  conda-forge
#     attr-2.5.1                 |       h166bdaf_0          69 KB  conda-forge
#     bzip2-1.0.8                |       h7f98852_4         484 KB  conda-forge
#     c-ares-1.18.1              |       h7f98852_0         113 KB  conda-forge
#     cairo-1.16.0               |    ha61ee94_1011         1.5 MB  conda-forge
#     dbus-1.13.6                |       h5008d03_3         604 KB  conda-forge
# ...

# %%
# !conda install -c conda-forge rtree
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - rtree
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     libspatialindex-1.9.3      |       h9c3ff4c_4         4.6 MB  conda-forge
#     rtree-1.0.0                |   py37h0b55af0_1          49 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         4.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   libspatialindex    conda-forge/linux-64::libspatialindex-1.9.3-h9c3ff4c_4
#   rtree              conda-forge/linux-64::rtree-1.0.0-py37h0b55af0_1
#
#
# Proceed ([y]/n)? y
#
#
# ...
# rtree-1.0.0          | 49 KB     | : 100% 1.0/1 [00:00<00:00,  8.55it/s]
# libspatialindex-1.9. | 4.6 MB    | : 100% 1.0/1 [00:00<00:00,  1.04it/s]
# done
# done
# done

# %%
# !conda install -c conda-forge pyembree
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - pyembree
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     embree-2.17.7              |       ha770c72_2        40.9 MB  conda-forge
#     pyembree-0.1.6             |   py37h0da4684_1          87 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        41.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   embree             conda-forge/linux-64::embree-2.17.7-ha770c72_2
#   pyembree           conda-forge/linux-64::pyembree-0.1.6-py37h0da4684_1
#
#
# Proceed ([y]/n)? y
#
#
# ...
# embree-2.17.7        | 40.9 MB   | : 100% 1.0/1 [00:08<00:00,  8.73s/it]
# pyembree-0.1.6       | 87 KB     | : 100% 1.0/1 [00:00<00:00,  9.12it/s]
# done
# done
# done

# %%
# !pip install trimesh
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 652 kB 2.8 MB/s
# ...

# %%
# !pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 511.7 MB 4.7 kB/s
# ...
#      |████████████████████████████████| 57 kB 4.8 MB/s
# ...
#      |████████████████████████████████| 14.5 MB 35.9 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 51.6 MB/s
# ...
#      |████████████████████████████████| 42 kB 1.5 MB/s
# ...
#      |████████████████████████████████| 2.4 MB 35.4 MB/s
# ...
#      |████████████████████████████████| 4.5 MB 38.2 MB/s
# ...
#      |████████████████████████████████| 40 kB 5.5 MB/s
# ...
#      |████████████████████████████████| 4.1 MB 39.7 MB/s
# ...
#      |████████████████████████████████| 123 kB 49.6 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 41.0 MB/s
# ...
#      |████████████████████████████████| 65 kB 4.1 MB/s
# ...
#      |████████████████████████████████| 75 kB 4.1 MB/s
# ...
#      |████████████████████████████████| 438 kB 34.6 MB/s
# ...
#      |████████████████████████████████| 5.8 MB 41.1 MB/s
# ...

# %%
# !conda install -c anaconda cudatoolkit
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - cudatoolkit
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cudatoolkit-11.3.1         |       h2bc3f7f_2       815.6 MB  anaconda
#     ------------------------------------------------------------
#                                            Total:       815.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   cudatoolkit        anaconda/linux-64::cudatoolkit-11.3.1-h2bc3f7f_2
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2022.6.1~ --> anaconda::ca-certificates-2022.4.26-h06a4308_0
#   certifi            conda-forge::certifi-2022.6.15-py37h8~ --> anaconda::certifi-2022.6.15-py37h06a4308_0
# ...

# %%
# !conda install -c anaconda cudnn
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - cudnn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cudnn-8.2.1                |       cuda11.3_0        1.32 GB  anaconda
#     ------------------------------------------------------------
#                                            Total:        1.32 GB
#
# The following NEW packages will be INSTALLED:
#
#   cudnn              anaconda/linux-64::cudnn-8.2.1-cuda11.3_0
#
#
# Proceed ([y]/n)? y
#
#
# ...
# cudnn-8.2.1          | 1.32 GB   | : 100% 1.0/1 [04:18<00:00, 258.68s/it]
# done
# done
# done

# %%
cd /content/drive/MyDrive/nerfactor-main
# Out:
# /content/drive/MyDrive/nerfactor-main

# %%
! python /content/drive/MyDrive/nerfactor-main/data_gen/merl/make_dataset.py
# Out:
# Training & Validation:   0% 0/100 [00:00<?, ?it/s]Loading MERL-BRDF:  /content/drive/MyDrive/data/brdfs/alum-bronze.binary
# Training & Validation:   1% 1/100 [00:39<1:04:37, 39.17s/it]Loading MERL-BRDF:  /content/drive/MyDrive/data/brdfs/alumina-oxide.binary
# Training & Validation:   2% 2/100 [01:42<1:27:31, 53.59s/it]Loading MERL-BRDF:  /content/drive/MyDrive/data/brdfs/aluminium.binary
# Training & Validation:   3% 3/100 [02:18<1:13:13, 45.29s/it]Loading MERL-BRDF:  /content/drive/MyDrive/data/brdfs/aventurnine.binary
# Training & Validation:   4% 4/100 [02:53<1:06:18, 41.44s/it]Loading MERL-BRDF:  /content/drive/MyDrive/data/brdfs/beige-fabric.binary
# Training & Validation:   5% 5/100 [03:27<1:01:27, 38.82s/it]Loading MERL-BRDF:  /content/drive/MyDrive/data/brdfs/black-fabric.binary
# Training & Validation:   6% 6/100 [04:01<58:13, 37.17s/it]  Loading MERL-BRDF:  /content/drive/MyDrive/data/brdfs/black-obsidian.binary
# ...

# %%
# !chmod +x /content/drive/MyDrive/nerfactor-main/nerfactor/trainvali_run.sh

# %%
# !chmod +x /content/drive/MyDrive/nerfactor-main/nerfactor/explore_brdf_space_run.sh

# %%
# !set CUDA_VISIBLE_DEVICES=0

# %%
#! /usr/bin/env
gpus='1'

# I. Learning BRDF Priors (training and validation)
proj_root='/content/drive/MyDrive'
repo_dir="$proj_root/nerfactor-main"
data_root="$proj_root/data/brdf_merl_npz/ims512_envmaph16_spp1"
outroot="$proj_root/data/output/train/merl"
viewer_prefix='http://vision38.csail.mit.edu' # or just use ''
# !REPO_DIR="/content/drive/MyDrive/nerfactor-main" "/content/drive/MyDrive/nerfactor-main/nerfactor/trainvali_run.sh" "$gpus" --config='brdf.ini' --config_override="data_root=/content/drive/MyDrive/data/brdf_merl_npz/ims512_envmaph16_spp1,outroot=/content/drive/MyDrive/data/output/train/merl,viewer_prefix=$viewer_prefix"

# II. Exploring the Learned Space (validation and testing)
ckpt="/content/drive/MyDrive/data/output/train/merl/lr1e-2/checkpoints/ckpt-50"
# !REPO_DIR="/content/drive/MyDrive/nerfactor-main" "/content/drive/MyDrive/nerfactor-main/nerfactor/explore_brdf_space_run.sh" "$gpus" --ckpt="$ckpt"
# Out:
# 2022-07-21 20:38:30.852901: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-21 20:38:30.852981: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (04d2a6c144d2): /proc/driver/nvidia/version does not exist
# 2022-07-21 20:38:30.854111: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# W0721 20:38:30.855279 139797603428224 cross_device_ops.py:1386] There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# ...
